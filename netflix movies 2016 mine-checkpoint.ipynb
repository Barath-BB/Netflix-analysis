# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
netflix = pd.read_csv("netflix _data_file.csv")
netflix.head(30)
# Out:
#    Show_Id Category                                Title  \
# 0       s1  TV Show                                   3%
# 1       s2    Movie                                07:19
# 2       s3    Movie                                23:59
# 3       s4    Movie                                    9
# 4       s5    Movie                                   21
# 5       s6  TV Show                                   46
# 6       s7    Movie                                  122
# 7       s8    Movie                                  187
# 8       s9    Movie                                  706
# 9      s10    Movie                                 1920
# 10     s11    Movie                                 1922
# 11     s12  TV Show                                 1983
# 12     s13  TV Show                                 1994
# 13     s14    Movie                                2,215
# 14     s15    Movie                                 3022
# ...

# %%
netflix.shape
# Out:
# (7789, 11)

# %%
netflix.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
netflix.describe() #gives every info
# Out:
#        Show_Id Category     Title                Director                Cast  \
# count     7789     7789      7789                    5401                7071
# unique    7787        2      7787                    4050                6831
# top       s684    Movie  Backfire  Raúl Campos, Jan Suter  David Attenborough
# freq         2     5379         2                      18                  18
#
#               Country     Release_Date Rating  Duration           Type  \
# count            7282             7779   7782      7789           7789
# unique            681             1565     14       216            492
# top     United States  January 1, 2020  TV-MA  1 Season  Documentaries
# freq             2556              118   2865      1608            334
#
#                                               Description
# count                                                7789
# unique                                               7769
# ...

# %%
netflix.isnull().sum() # to find missing value it seems the director and cast and country and date has misisng value...
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# handling the missing value
netflix["Director"].fillna("Unknown")
# Out:
# 0                 unknown
# 1       Jorge Michel Grau
# 2            Gilbert Chan
# 3             Shane Acker
# 4          Robert Luketic
#               ...
# 7784          Josef Fares
# 7785          Mozez Singh
# 7786              unknown
# 7787              unknown
# 7788             Sam Dunn
# Name: Director, Length: 7789, dtype: object

# %%
netflix["Cast"].fillna("unknown")
# Out:
# 0       João Miguel, Bianca Comparato, Michel Gomes, R...
# 1       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3       Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#                               ...
# 7784    Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                              Nasty C
# 7787                           Adriano Zumbo, Rachel Khoo
# 7788                                              Unknown
# Name: Cast, Length: 7789, dtype: object

# %%
netflix["Country"].fillna("unknown")
# Out:
# 0                                                  Brazil
# 1                                                  Mexico
# 2                                               Singapore
# 3                                           United States
# 4                                           United States
#                               ...
# 7784    Sweden, Czech Republic, United Kingdom, Denmar...
# 7785                                                India
# 7786                                              Unknown
# 7787                                            Australia
# 7788                United Kingdom, Canada, United States
# Name: Country, Length: 7789, dtype: object

# %%
# now release_data is a string but its  date-time  format
 #using format ="mixed"Automatically detects and converts different date formats. and using error="coerce"onverts invalid dates to NaT (Not a Time) instead of crashing.
netflix["Release_Date"] = pd.to_datetime(netflix["Release_Date"],format ='mixed',errors = 'coerce')

# %%
# working or not
netflix.info()
netflix['Release_Date'].head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      7789 non-null   object
#  4   Cast          7789 non-null   object
#  5   Country       7789 non-null   object
#  6   Release_Date  7779 non-null   datetime64[ns]
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 669.5+ KB
# 0   2020-08-14
# 1   2016-12-23
# 2   2018-12-20
# 3   2017-11-16
# 4   2020-01-01
# 5   2017-07-01
# 6   2020-06-01
# 7   2019-11-01
# 8   2019-04-01
# 9   2017-12-15
# Name: Release_Date, dtype: datetime64[ns]

# %%
#extract yyear and day and month

netflix["Year"] = netflix["Release_Date"].dt.year
netflix['Year'].value_counts().head(10)
# Out:
# Year
# 2019.0    2154
# 2020.0    2010
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# Name: count, dtype: int64

# %%
netflix["Month"] = netflix["Release_Date"].dt.month
netflix["Day"] = netflix["Release_Date"].dt.day

# %%
netflix['Month'].value_counts().head(10)
# Out:
# Month
# 12.0    833
# 10.0    785
# 1.0     757
# 11.0    738
# 3.0     669
# 9.0     620
# 8.0     618
# 4.0     602
# 7.0     600
# 5.0     543
# Name: count, dtype: int64

# %%
netflix['Day'].value_counts().head(10)
# Out:
# Day
# 1.0     2069
# 15.0     644
# 31.0     274
# 2.0      247
# 16.0     240
# 20.0     219
# 10.0     213
# 5.0      208
# 19.0     203
# 8.0      190
# Name: count, dtype: int64

# %%
#using specific year
netflix_2017 = netflix[netflix["Year"]== 2017]
print(netflix_2021.shape)
# Out:
# (0, 14)

# %%
print(netflix.columns)
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description', 'Year',
#        'Month', 'Day'],
#       dtype='object')

# %%
netflix_2015 = netflix[netflix["Year"] == 2015]
print(netflix_2022.shape)
# Out:
# (2, 14)

# %%
# reattemt
netflix["Year"] = netflix["Release_Date"].dt.year

# %%
print(netflix["Year"].unique())  # See available years
# Out:
# [2020. 2016. 2018. 2017. 2019. 2021. 2015. 2013. 2011.   nan 2012. 2014.
#  2008. 2009. 2010. 2022.]

# %%
# creating the new data for 2022 year netflix
new_data = pd.DataFrame({
    "Show_Id": ["S12345", "S12346"],
    "Category": ["Movie", "TV Show"],
    "Title": ["Sample Movie", "Sample Show"],
    "Director": ["John Doe", "Jane Doe"],
    "Cast": ["Actor A, Actor B", "Actor C, Actor D"],
    "Country": ["USA", "UK"],
    "Release_Date": pd.to_datetime(["2021-06-15", "2022-08-20"]),
    "Rating": ["PG-13", "TV-MA"],
    "Duration": ["90 min", "2 Seasons"],
    "Type": ["Action", "Drama"],
    "Description": ["This is a sample movie.", "This is a sample show."],
    "Year": [2021, 2022]
})

netflix = pd.concat([netflix, new_data], ignore_index=True)

# %%
netflix_2022 = netflix[netflix["Year"] == 2022]
print(netflix_2022.shape)
# Out:
# (3, 14)

# %%
print(netflix_2022)
# Out:
#      Show_Id Category        Title  Director              Cast Country  \
# 7790  S12346  TV Show  Sample Show  Jane Doe  Actor C, Actor D      UK
# 7792  S12346  TV Show  Sample Show  Jane Doe  Actor C, Actor D      UK
# 7794  S12346  TV Show  Sample Show  Jane Doe  Actor C, Actor D      UK
#
#      Release_Date Rating   Duration   Type             Description    Year  \
# 7790   2022-08-20  TV-MA  2 Seasons  Drama  This is a sample show.  2022.0
# 7792   2022-08-20  TV-MA  2 Seasons  Drama  This is a sample show.  2022.0
# 7794   2022-08-20  TV-MA  2 Seasons  Drama  This is a sample show.  2022.0
#
#       Month  Day
# 7790    NaN  NaN
# 7792    NaN  NaN
# 7794    NaN  NaN

# %%
print(netflix_2016)
# Out:
#      Show_Id Category               Title  \
# 1         s2    Movie               07:19
# 25       s26    Movie            (T)ERROR
# 35       s36    Movie           #Rucker50
# 59       s60    Movie     1000 Rupee Note
# 62       s63    Movie          13 Cameras
# ...      ...      ...                 ...
# 7735   s7734  TV Show   You're My Destiny
# 7739   s7738    Movie         Young Tiger
# 7742   s7741  TV Show   Your lie in April
# 7769   s7768  TV Show  Zindagi Gulzar Hai
# 7772   s7771    Movie             Zinzana
#
#                                     Director  \
# 1                          Jorge Michel Grau
# 25    Lyric R. Cabral, David Felix Sutcliffe
# 35                     Robert McCullough Jr.
# 59                            Shrihari Sathe
# 62                            Victor Zarcoff
# ...                                      ...
# 7735                                 unknown
# 7739                                  Mu Chu
# ...

# %%
print(netflix_2022['Category'].unique()) #which one is unique
# Out:
# ['TV Show']

# %%
print(netflix_2022['Director'].mode())  # to find most common director
# Out:
# 0    Jane Doe
# Name: Director, dtype: object

# %%
print(netflix_2016["Category"].value_counts()) # to check how many tv shows and movie released use value.counts()
# Out:
# Category
# Movie      258
# TV Show    185
# Name: count, dtype: int64

# %%
# now bar time  # wrong one
import matplotlib.pyplot as plt  
netflix_2016["Month"].value_counts().sort_index().plot(kind="bar")
plt.xlabel("Month")
plt.ylabel("Count")
plt.table("Netflix releases per month in 2016(kinda old data but its still relevent lol)")
plt.show()
plt.xticks(range(1,13), labels =["jan","feb","mar","apr","may","june","july","aug","sep","oct","nov","dec"])
# Out:
# ([<matplotlib.axis.XTick at 0x27d6b7f5d00>,
# ...
#  [Text(1, 0, 'jan'),
#   Text(2, 0, 'feb'),
#   Text(3, 0, 'mar'),
#   Text(4, 0, 'apr'),
#   Text(5, 0, 'may'),
#   Text(6, 0, 'june'),
#   Text(7, 0, 'july'),
#   Text(8, 0, 'aug'),
#   Text(9, 0, 'sep'),
#   Text(10, 0, 'oct'),
#   Text(11, 0, 'nov'),
#   Text(12, 0, 'dec')])

# %%
import matplotlib.pyplot as plt   #new one
netflix_2016["Month"].value_counts().sort_index().plot(kind="bar")
plt.xlabel("Month")
plt.ylabel("Count")
plt.table("Netflix releases per month in 2016(kinda old data but its still relevent lol)")
plt.xticks(range(1,13), labels =["jan","feb","mar","apr","may","june","july","aug","sep","oct","nov","dec"])
plt.show()

# %%
import matplotlib.pyplot as plt   #new one
netflix_2018["Month"].value_counts().sort_index().plot(kind="bar")
plt.xlabel("Month")
plt.ylabel("Count")
plt.table("Netflix releases per month in 2018")
plt.xticks(range(1,13), labels =["jan","feb","mar","apr","may","june","july","aug","sep","oct","nov","dec"])
plt.show()

# %%
# Using more professional way and design
import matplotlib.pyplot as plt  
netflix_2016["Month"].value_counts().sort_index().plot(kind="bar",color="crimson",edgecolor="black") # design colors
plt.xlabel("Month")
plt.ylabel("Count")
plt.table("Netflix releases per month in 2016(kinda old data but its still relevent lol)")
plt.xticks(range(1,13), labels =["jan","feb","mar","apr","may","june","july","aug","sep","oct","nov","dec"]);
plt.show()

# %%
# another design after plot s font sizes
plt.xlabel("Month", fontsize=12, fontweight="bold")
plt.ylabel("Count", fontsize=12, fontweight="bold")
plt.title("Netflix Releases Per Month (2016)", fontsize=14, fontweight="bold")

plt.xticks(rotation=45, ha="right")
plt.grid(axis = "y", linestyle ="--", alpha = 0.7)
plt.box(False) # used to remove chart boxes
plt.show()

# %%
# now combining both
 #another design after plot s font sizes
netflix_2016["Month"].value_counts().sort_index().plot(kind="bar",color="crimson",edgecolor="black") # design colors
plt.xlabel("Month")
plt.ylabel("Count")
plt.table("Netflix releases per month in 2016(kinda old data but its still relevent lol)")
plt.xticks(range(1,13), labels =["jan","feb","mar","apr","may","june","july","aug","sep","oct","nov","dec"]);
plt.xlabel("Month", fontsize=12, fontweight="bold")
plt.ylabel("Count", fontsize=12, fontweight="bold")
plt.title("Netflix Releases Per Month (2016)", fontsize=14, fontweight="bold")

plt.xticks(rotation=45, ha="right")
plt.grid(axis = "y", linestyle ="--", alpha = 0.7)
plt.box(False) # used to remove chart boxes

plt.show()

# %%
#Another chart with more aesthetic way
plt.figure(figsize=(10, 6))  # Adjust figure size  

netflix_2016["Month"].value_counts().sort_index().plot(
    kind="bar", 
    color="crimson",  # Bar color  
    edgecolor="black"  # Bar border  
)  
plt.xlabel("Month", fontsize=12, fontweight="bold")  # X-axis label  
plt.ylabel("Count", fontsize=12, fontweight="bold")  # Y-axis label  
plt.title("Netflix Releases Per Month (2016)", fontsize=14, fontweight="bold", color="darkred")  # Title  
plt.xticks(rotation=40, fontsize=10)  # Rotate x-axis labels  
plt.grid(axis="y", linestyle="--", alpha=0.7)  # Add horizontal grid lines  

# Hide unnecessary chart borders  
plt.gca().spines["top"].set_visible(False)  
plt.gca().spines["right"].set_visible(False)  

plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 Image("Netflix 2016_analysis.png")
#
# NameError: name 'Image' is not defined
